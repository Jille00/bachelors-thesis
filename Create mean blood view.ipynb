# %%
from main import *
from collections import Counter

# %%
results = run_dimension(dimensions=6,
              n_neighbors=50,
              min_dist=0.0,
              min_cluster_size=1000,
              min_samples=10,
              frames=True)
# Out:
# Loading saved data...
# Data loaded in: 25.300400018692017 seconds
# Loading saved embedding...
# Embedding loaded in: 3.559799909591675 seconds
# HDBSCAN does not classify 21692 samples

# %%
results
# Out:
#                     cluster size    c_b_wbc   c_b_wvf    c_b_neu    c_b_seg  \
# cluster_assignment
# 4.0                     951367.0   8.319155  0.992233   5.596649   5.596649
# 6.0                     535467.0   9.076856  0.992368   6.268474   6.268474
# 32.0                     45853.0   7.400904  0.989136   5.782946   5.782946
# 0.0                      42524.0   8.930552  0.990638   5.680867   5.680107
# 27.0                     31248.0  18.191256  0.984667  15.464219  12.004511
# ...                          ...        ...       ...        ...        ...
# 19.0                      1098.0   9.183481  0.982106   6.182138   6.182138
# 60.0                      1072.0  19.884436  0.972950  15.962490  12.176310
# 72.0                      1053.0   1.262294  0.964578   0.666097   0.608893
# 25.0                      1050.0  19.308462  0.942795  12.319494  11.056001
# 17.0                      1019.0   5.428679  0.972585   3.479554   3.130057
#
# ...

# %%
PATH = 'C:/Users/jtogt2/Notebook/umcu-stage/'
results.to_excel('final_means_1.xlsx')
