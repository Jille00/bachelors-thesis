# %%
from load_data import *
import pandas as pd
import numpy as np

# %%
loader = LoadData()

# %%
loader.load_celldyn()

# %%
loader.preprocess()

# %%
df = loader.retrieve_processed_frame()

# %%
df.head()
# Out:
#         studyId_Alle_celldyn   c_b_wbc   c_b_wvf   c_b_neu   c_b_seg  \
# 322654          4.478707e+09  2.195780 -0.002545  1.894648  1.894648
# 322655          5.737137e+09  2.105555 -0.005503  1.727456  1.727456
# 322656          1.138214e+09  1.234867 -0.005151  0.494373  0.494373
# 322657          3.498087e+09  2.197248 -0.001673  2.124826  2.124826
# 322658          5.075906e+09  3.389597 -0.014272  3.221141  3.166407
#
#           c_b_bnd     c_b_ig   c_b_lym  c_b_lyme   c_b_vlym  ...  c_b_rbcicv  \
# 322654 -46.051702 -46.051702  0.525899  0.525899 -46.051702  ...    0.532526
# 322655 -46.051702 -46.051702  0.669249  0.669249 -46.051702  ...    0.605119
# 322656 -46.051702 -46.051702  0.192552  0.192552 -46.051702  ...    0.483746
# 322657 -46.051702 -46.051702 -0.844491 -0.844491 -46.051702  ...    0.408753
# 322658   0.288669 -46.051702  0.688280  0.688280 -46.051702  ...    0.403830
#
#         c_b_rbcfmn  c_b_rbcfcv  c_b_rtcfmn  c_b_rtcfcv    c_b_hb   c_b_mch  \
# ...
